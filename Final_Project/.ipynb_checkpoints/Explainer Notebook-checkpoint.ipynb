# %% [markdown]
# # Final Project - Explainer Notebook

# %% [markdown]
# The dataset used in the project is downloaded from https://www.opendata.dk/city-of-copenhagen/trae_basis. The dataset contains all trees (park trees, street trees etc.) which are next to the communal roads of Copenhagen muncipality. Many larger parks such as 'Kongens Have', 'Kalvebod Brygge' and 'Botanisk Have' are therefor not included in the dataset making it somewhat in complete. The dataset contains 59627 observations (trees) and has 183 features of which most are filled primarily with ``NaN`` values.
#
# The particular dataset was chosen as the authors of the notebook were very amazed by the visualization of the New York City street trees: https://www.cloudred.com/labprojects/nyctrees/. The New York City visualization led to a curiosity to finding out how the tree types of Copenhagen were distributed across districts and what stories could be told about the street trees of Copenhagen.
#
# The end goal was to take the user through the story about the street trees of Copenhagen. The idea is to show how the trees are distributed across the different districts of Copenhagen allowing the user to interact with the visualization and find what kind of trees might be close to the person. Besides this the idea was also to tell a different and original story, to make a seemingly boring dataset come to life and entertain the user.

# %% [markdown]
# ## Basic Stats
#
# In this section the dataset is introduced and preproccesed for furhter analysis.
#
# First packages are imported and the dataset is loaded.

# %%
# Standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
# %matplotlib inline

# %%
# Import data
df = pd.read_csv("trae_basis.csv", low_memory=False)
df.shape
# Out:
# (59627, 183)

# %%
pd.set_option('display.max_columns', None) # Show all columns
df.head()
# Out:
#             FID kategori saerligt_trae     id     type        element  \
# 0  trae_basis.1  gadetræ           nej  18611  2 Træer  2.3 Parktræer
# 1  trae_basis.2  gadetræ           nej  21291  2 Træer  2.3 Parktræer
# 2  trae_basis.3  gadetræ           nej  21292  2 Træer  2.3 Parktræer
# 3  trae_basis.4  gadetræ           nej  21293  2 Træer  2.3 Parktræer
# 4  trae_basis.5  gadetræ           nej  21294  2 Træer  2.3 Parktræer
#
#   under_element ny_dm_element ny_dm_under_element  arbsted_tekst_id  \
# 0           NaN     Gadetræer             Gadetræ  Gadet_Gadet_3421
# 1           NaN     Gadetræer             Gadetræ  Gadet_Gadet_3421
# 2           NaN     Gadetræer             Gadetræ  Gadet_Gadet_3421
# 3           NaN     Gadetræer             Gadetræ  Gadet_Gadet_3421
# 4           NaN     Gadetræer             Gadetræ  Gadet_Gadet_3421
#
#                    driftsplan_navn enhedsomraade              traeart  \
# ...

# %% [markdown]
#  The dataset contains 59.627 trees with 183 features. With this many features a thorough selection is needed to select only the most relevant features. Most of these features are related to maintanace of the trees such as a feature indicating root damage and one indicating fungy which were deemed uninteresting for the scope of this project. The most interesting features are chosen to be the ones listed below:
#
# - ``planteaar``, the planting year of the tree.
# - ``wkb_geometry``, the coordinates for each tree.
# - ``donor``, the donor of a tree if it has any.
# - ``trae_historie``, specifies if the tree has any specific history.
# - ``botanisk_interesse``, specifies if the tree has a specific botanical interest.
# - ``slaegtsnavn``, the family name of the tree.
# - ``bydelsnavn``, the name of the city district in which the tree is positioned in.
# - ``ejer``, the owners of the tree.
# - ``id``, a specific id unique for each tree.
#
# The dataset is therefor limited to only these features.

# %%
focus_features = ['id','slaegtsnavn','bydelsnavn','wkb_geometry','planteaar','donor','trae_historie',
                  'ejer','botanisk_interesse']
df=df[focus_features]
df.head()
# Out:
#       id slaegtsnavn                 bydelsnavn  \
# 0  18611        Lind  Vesterbro-Kongens Enghave
# 1  21291        Lind  Vesterbro-Kongens Enghave
# 2  21292        Lind  Vesterbro-Kongens Enghave
# 3  21293        Lind  Vesterbro-Kongens Enghave
# 4  21294        Lind  Vesterbro-Kongens Enghave
#
#                                     wkb_geometry  planteaar donor  \
# 0      POINT (12.5370471883976 55.6486340745573)     1953.0   NaN
# 1   POINT (12.536925020477707 55.64867988581558)     1953.0   NaN
# 2   POINT (12.537000905330974 55.64876361021244)     1953.0   NaN
# 3   POINT (12.537133269649273 55.64872321507861)     1953.0   NaN
# 4  POINT (12.537399549194998 55.648992732825036)     1953.0   NaN
#
#       trae_historie ejer botanisk_interesse
# 0  Ikke registreret  TMF   Ikke registreret
# 1  Ikke registreret  TMF   Ikke registreret
# 2  Ikke registreret  TMF   Ikke registreret
# 3  Ikke registreret  TMF   Ikke registreret
# 4  Ikke registreret  TMF   Ikke registreret

# %% [markdown]
# Below the feature ``slaegtsnavn`` is examined.

# %%
traer = df.groupby(['slaegtsnavn']).count().id
traer = traer.sort_values(ascending=False)
plt.rcParams['figure.figsize'] = (12, 5)
plt.bar(traer.index,traer.values)
plt.title("Tree family names")
plt.ylabel("Tree counts")
plt.xticks(rotation=90)
plt.show()
print("Number of tree families:",len(traer))
# Out:
# Number of tree families: 74

# %% [markdown]
# The plot shows that most of the tree family names are not registred trees (Ikke registreret) and that in total there are 74 tree family names. The columns ``traeart``(tree type) and ``dansk_navn``(danish name) could also have been used. But these features had too many unique names for usage (+300) which would make the visualizations too confusing.

# %% [markdown]
# There are some trees which have a ``NaN`` entry as their family name, this is changed to *Ikke registreret* (Not registered).

# %%
df.slaegtsnavn = df.slaegtsnavn.fillna("Ikke registreret")

# %% [markdown]
# As all the tree names currently are listed in danish the names are translated to english and showed in the column ``slaegtsnavn_eng``.

# %%
df['slaegtsnavn_eng']=df['slaegtsnavn']
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Ikke registreret', 'Not registered', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Lind', 'Linden', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Platan', 'Plane', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Kirsebær/Blomme', 'Cherry/Plum', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Røn', 'Rowan', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Løn', 'Maple', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Ask', 'Ash', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Eg', 'Oak', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Løn', 'Maple', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Robinie', 'Black locust', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Hestekastanie', 'Horse chestnut', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Birk', 'Birch', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Poppel', 'Poplar', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Æble', 'Apple', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Tjørn', 'Hawthorn', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Avnbøg', 'Hornbeam', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Fyr', 'Pine', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Pil', 'Willow', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Elm', 'Generic', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('El', 'Alder', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Generic', 'Elm', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Hassel', 'Hazel', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Tretorn', 'Honey locust', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Gran', 'Spruce', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Pære', 'Pear', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Vandgran', 'Dawn redwood', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Taks', 'Yew', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Skyrækker', 'Tree of heaven', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Bøg', 'Beech', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Tulipantræ', 'Tulip tree', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Ambratræ', 'Sweetgum', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Dværgcypres', 'False cypress', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Bærmispel', 'Juneberry', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Lærk', 'Larch', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Kastanie', 'Chestnut', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Guldregn', 'Golden rain', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Kornel', 'Cornus', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Ceder', 'Cedar', regex=False)
df['slaegtsnavn_eng']=df['slaegtsnavn_eng'].str.replace('Valnød', 'Walnut', regex=False)

# %% [markdown]
# From the plot it can further be noticed that several trees have very few observations. To make the visualizations more simple all trees which have less than 25 observations are labeled as ``Minority trees``.

# %%
minority= df.groupby('slaegtsnavn').count()['id'][:]<25
minority=minority[minority==True]

for i in range(len(df['slaegtsnavn'])):
    if(df['slaegtsnavn'].iloc[i] in minority):
           df['slaegtsnavn_eng'].iloc[i]='Minority trees'
            
print("Tree names left:", len(df['slaegtsnavn_eng'].unique()))
# Out:
# C:\Anaconda\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Tree names left: 41

# %% [markdown]
# The data is thereby limited to 41 different tree types.
#
# Another feature which was found to be important was the column ``bydelsnavn``(district name), below the distribution for this feature is shown. ``nan`` values are also dropped from the column.

# %%
df=df.dropna(how='any', subset=['bydelsnavn']) # Drop Nan
# Bar chart
byer = df.groupby(['bydelsnavn']).count().id
plt.rcParams['figure.figsize'] = (12, 5)
plt.bar(byer.index,byer.values)
plt.title("Tree counts pr. district")
plt.ylabel("Tree counts")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# From the graph it can be seen that the trees are distributed across 10 different districts. It should be noticed that Frederiksberg is not a part of these districts as Frederiksberg is a seperate municipality and not a part of the municipality of Copenhagen. The district *Vesterbro-Kongens Enghave* is changed to *Vesterbro* for simplicity.

# %%
df['bydelsnavn']=df['bydelsnavn'].str.replace('Vesterbro-Kongens Enghave', 'Vesterbro', regex=False)

# %% [markdown]
# To use the feature ``planteaar`` the ``0`` entries and ``NaN`` values are filled with ``Not registered`` instead.

# %%
df['planteaar'].replace(0, 'Not registered', inplace=True)
df['planteaar'] = df['planteaar'].fillna('Not registered')
df['planteaar'].unique()
# Out:
# array([1953.0, 1948.0, 'Not registered', 2001.0, 1993.0, 2019.0, 1995.0,
#        2012.0, 2013.0, 2005.0, 2018.0, 2016.0, 1900.0, 1978.0, 1992.0,
#        2014.0, 1950.0, 1970.0, 1960.0, 1986.0, 1930.0, 1990.0, 1980.0,
#        1971.0, 1985.0, 2000.0, 2004.0, 1945.0, 1955.0, 1910.0, 1880.0,
#        2003.0, 2006.0, 1975.0, 1940.0, 1969.0, 1920.0, 2009.0, 2010.0,
#        1982.0, 1954.0, 2015.0, 1999.0, 2007.0, 1983.0, 1890.0, 1997.0,
#        1942.0, 1998.0, 1984.0, 2020.0, 1939.0, 1926.0, 1991.0, 2011.0,
#        1974.0, 1951.0, 2008.0, 1946.0, 2002.0, 1965.0, 2017.0, 1902.0,
#        1952.0, 1932.0, 1988.0, 1850.0, 1944.0, 1976.0, 1923.0, 1967.0,
#        1924.0, 1977.0, 1987.0, 1941.0, 1931.0, 1901.0, 1936.0, 1973.0,
#        1908.0, 1907.0, 1933.0, 1916.0, 1957.0, 1919.0, 1925.0, 1906.0,
#        1943.0, 1935.0, 1981.0, 1927.0, 1972.0, 1979.0, 1989.0, 1909.0,
#        1912.0, 1994.0, 1947.0, 1934.0, 1891.0, 1922.0, 1895.0, 1914.0,
# ...

# %% [markdown]
# For the features ``donor``, ``ejer``, ``trae_historie`` and ``botanisk_interesse`` the category names are translated. If any ``nan`` values are present these are changed to ``Not registered``.

# %%
df['donor']=df['donor'].str.replace('Eventyrernes klub', 'The Adventurers’ Club of Denmark', regex=False)
df['donor']=df['donor'].str.replace('Jf Peder Clement, modtaget fra Ålholm Arboret', 'Jf Peder Clement, received from Ålholm Arboret', regex=False)
df['donor']=df['donor'].str.replace('Journalistforbundet, American Red Wood Association', 'The journalist association, American Red Wood Association', regex=False)
df['donor']=df['donor'].str.replace('Indsamling i England og Danmark', 'Collection in England and Denmark', regex=False)
df['donor']=df['donor'].str.replace('Det Danske samfund i Østrig v. Barbara Kauders', 'Danish society in Austria w. Barbara Kauders', regex=False)
df['donor']=df['donor'].str.replace('Gartneribrugets afsætningsudvalg', 'Horticultural Farms Marketing Committee', regex=False)
df['donor']=df['donor'].str.replace('Foreningen til Hovedstadens Forskønnelse', 'The Association for the beutification of the capital', regex=False)
df['donor']=df['donor'].str.replace('Danmarks naturfrednings Forening', 'The Danish Society for Nature Conservation', regex=False)
df['donor']=df['donor'].str.replace('Den makedonske Ambassade', 'The Macedonian Embassy', regex=False)
df['donor']=df['donor'].str.replace('Plant et træ', 'Plant a tree', regex=False)
df['donor']=df['donor'].str.replace('Det Kgl. Danske Kunstakademi', 'Royal Danish Academy of Fine Arts', regex=False)
df['donor']=df['donor'].str.replace('SITAS planteskole', 'SITAS', regex=False) # The same as SITAS
df['donor']=df['donor'].str.replace('SITAS', 'SITAS nursery', regex=False)
df['donor']=df['donor'].fillna('Not registered')
df['donor'].unique()
# Out:
# array(['Not registered', 'The Adventurers’ Club of Denmark',
#        'Jf Peder Clement, received from Ålholm Arboret',
#        'The journalist association, American Red Wood Association',
#        'SITAS nursery', 'Collection in England and Denmark',
#        'Danish society in Austria w. Barbara Kauders',
#        'Horticultural Farms Marketing Committee',
#        'The Association for the beutification of the capital',
#        'The Danish Society for Nature Conservation',
#        'Jugendaustauschwerk im Kreis Gütersloh E.V.',
#        'The Macedonian Embassy',
#        'Tokyo by v. Dr.Ryotaro Azuma, Governor of Tokyo',
#        'Guangzhou International Award for Urban Innovation',
#        'Valby Rotary Club', 'FTM', 'Plant a tree', 'Lions Club',
#        'Royal Danish Academy of Fine Arts', 'DSB'], dtype=object)

# %%
df['ejer']=df['ejer'].str.replace('Privat', 'Private', regex=False)
df['ejer']=df['ejer'].str.replace('KK andre end TMF', 'KK other than TMF', regex=False)
df['ejer']=df['ejer'].str.replace('Ikke registreret', 'Not registered', regex=False)
df['ejer']=df['ejer'].fillna('Not registered')
df['ejer'].unique()
# Out:
# array(['TMF', 'Private', 'Not registered', 'KK other than TMF'],
#       dtype=object)

# %%
df['trae_historie']=df['trae_historie'].str.replace('Ikke registreret','Not registered',regex=False)
df['trae_historie']=df['trae_historie'].str.replace('Beskyttet via frivillig aftale','Protected through voluntary agreement',regex=False)
df['trae_historie']=df['trae_historie'].str.replace('Hæderstræ','Honor tree',regex=False)
df['trae_historie']=df['trae_historie'].str.replace('Donationstræ','Donation tree',regex=False)
df['trae_historie']=df['trae_historie'].str.replace('Kulturhistorisk','Cultural historical',regex=False)
df['trae_historie']=df['trae_historie'].fillna('Not registered')
df['trae_historie'].unique()
# Out:
# array(['Not registered', 'Protected through voluntary agreement',
#        'Honor tree', 'Donation tree', 'Cultural historical'], dtype=object)

# %%
df['botanisk_interesse']=df['botanisk_interesse'].str.replace('Ikke registreret','Not registered',regex=False)
df['botanisk_interesse']=df['botanisk_interesse'].str.replace('Ja','Yes',regex=False)
df['botanisk_interesse']=df['botanisk_interesse'].fillna('Not registered')
df['botanisk_interesse'].unique()
# Out:
# array(['Not registered', 'Yes'], dtype=object)

# %% [markdown]
# As the feature ``wkb_geometry`` is in a string format the ``X`` and ``Y`` coordinates are taken from the column and added as seperate features.

# %%
# Reset index for the for look to work
df=df.reset_index(drop=True)

# Initialize columns
df['X']=np.zeros(len(df))
df['Y']=np.zeros(len(df))

# Loop over all trees and calculate the respective coordinates
for i in range(len(df)):
    # Exstracting the latitude and longitude coordinates
    temp = df.loc[i,'wkb_geometry'].split()
    df.loc[i,'X']=float(temp[1][1:])
    df.loc[i,'Y']=float(temp[2][:-1])

# %% [markdown]
# To avoid having to run all the code above everytime, the dataframe is saved as ``DataTransformed.csv`` and loaded again after.

# %%
#df.to_csv('DataTransformed.csv')
df = pd.read_csv('DataTransformed.csv')
df = df.drop("Unnamed: 0",axis=1)
df.head()
# Out:
#       id slaegtsnavn bydelsnavn  \
# 0  18611        Lind  Vesterbro
# 1  21291        Lind  Vesterbro
# 2  21292        Lind  Vesterbro
# 3  21293        Lind  Vesterbro
# 4  21294        Lind  Vesterbro
#
#                                     wkb_geometry planteaar           donor  \
# 0      POINT (12.5370471883976 55.6486340745573)    1953.0  Not registered
# 1   POINT (12.536925020477707 55.64867988581558)    1953.0  Not registered
# 2   POINT (12.537000905330974 55.64876361021244)    1953.0  Not registered
# 3   POINT (12.537133269649273 55.64872321507861)    1953.0  Not registered
# 4  POINT (12.537399549194998 55.648992732825036)    1953.0  Not registered
#
#     trae_historie ejer botanisk_interesse slaegtsnavn_eng          X  \
# 0  Not registered  TMF     Not registered          Linden  12.537047
# 1  Not registered  TMF     Not registered          Linden  12.536925
# 2  Not registered  TMF     Not registered          Linden  12.537001
# ...

# %%
df.shape
# Out:
# (57039, 12)

# %% [markdown]
# The dataset thereby is reduced to 12 features and 57039 observations.
#
# To further get a quick understanding of how the trees are distributed a heatmap is plotted for all the observations using ``folium``.

# %%
import folium
from folium.plugins import HeatMap

heat_trees = df[['Y','X']]

# List comprehension to make out list of lists
heat_data = [[row['Y'],row['X']] for index, row in heat_trees.iterrows()]

# Plot it on the map
map_heat_cph = folium.Map([55.687784, 12.541356],tiles="Stamen Terrain" ,zoom_start = 12)
HeatMap(heat_data, radius=11, max_zoom=18).add_to(map_heat_cph)
# Display the map
map_heat_cph
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The map shows how no trees are visible in Frederiksberg as mentioned earlier. The map further shows that alot of trees are focused in the area of Østerbro/Nørrebro.
#
#
# To enrich the dataset information about the population, area and average $m^2$ price of an apartment in each of the districts are gathered from:
# - https://statistikbanken.kk.dk/1050dc07-e88c-4206-ae4e-645718e26ab9/ReportSection, information about the population, numbers are from end of 2019.
# - https://www.kk.dk/sites/default/files/2016_befolkningen_efter_bydele_og_areal.pdf, information about the areas of the districts, number are from 2010.
# - https://rkr.statistikbank.dk/statbank5a/SelectVarVal/Define.asp?MainTable=BM011&TabStrip=Select&PLanguage=0&FF=20, information about the average $m^2$ price for an appartment, numbers are an average over all four quaters of 2019.
# (The districts correspond to the following postcodes, Kbh K = Indre by, Kbh V + Kbh S = Vesterbro, Kbh Ø = Østerbro, Kbh N = Nørrebro, Kbh NV = Bisperbjerg, Valby = Valby, Vanløse = Vanløse, Brønshøj = Husum/Brønshøj, Kbh S = Amager Øst and Amager Vest). It was not possible to find a seperate prices for Amager Øst and Vest it was therefor assumed that these would be the same eventhough the real prices will most likely differ.

# %%
# Population data
district1 = ['Indre By', 'Østerbro','Nørrebro','Vesterbro','Valby','Vanløse',
        'Brønshøj-Husum','Bispebjerg','Amager Øst','Amager Vest']
population = [55866,79803,80254,72688,60308,41195,44784,55172,59803,78973] # Population per 31 jan 2019: https://statistikbanken.kk.dk/1050dc07-e88c-4206-ae4e-645718e26ab9/ReportSection
temp1 = pd.DataFrame({'district':district1,'population':population})

# Area data
district2 = ['Indre By','Østerbro','Nørrebro','Vesterbro','Valby',
            'Vanløse','Brønshøj-Husum','Bispebjerg','Amager Øst','Amager Vest']
area = [9, 8.7, 4.1, 8.2, 9.2, 6.7, 8.7, 6.8, 9.1, 19.2] # area in km^2
temp2 = pd.DataFrame({'district':district2,'area':area})

# m^2 price data
district3 = ['Indre By','Østerbro','Nørrebro','Vesterbro','Valby',
            'Vanløse','Brønshøj-Husum','Bispebjerg','Amager Øst','Amager Vest']
squaremeter_price = [(49345+50292+50045+51871)/4 , (45241+44879+43929+44924)/4,  #(Kbh K, Kbh Ø)
                      (43162+42342+42687+42860)/4,                                #(Kbh N)
                      ((45770+44626+44031+46182)/4+(38045+39072+38806+39110)/4)/2,#((Kbh V+SV)/2)
                      (33498+34168+33967+34034)/4, (33767+33159+34105+34003)/4,   #(Valby, Vanløse)
                      (31241+29304+30023+29554)/4, (32547+33686+33914+33556)/4,   #(Brønshøj, Bispebjerg)
                      (37705+38157+38459+38535)/4,(37705+38157+38459+38535)/4]    #(Kbh S, Kbh S)
temp3 = pd.DataFrame({'district':district3,'squaremeter_price':squaremeter_price})
temp3.squaremeter_price = temp3.squaremeter_price.round(0)

# The tree counts
trees = df.groupby(['bydelsnavn']).count().id
temp4 = pd.DataFrame({'district':trees.index,'trees':trees.values})

temp11 = pd.merge(temp1,temp2,on='district')
temp12 = pd.merge(temp11,temp3,on='district')
df2 = pd.merge(temp12,temp4,on='district')
df2 = df2.sort_values('district', ascending=True) # Sort alphabetically
df2
# Out:
#          district  population  area  squaremeter_price  trees
# 9     Amager Vest       78973  19.2            38214.0   4477
# 8      Amager Øst       59803   9.1            38214.0   3930
# 7      Bispebjerg       55172   6.8            33426.0   8268
# 6  Brønshøj-Husum       44784   8.7            30030.0   4151
# 0        Indre By       55866   9.0            50388.0   6105
# 2        Nørrebro       80254   4.1            42763.0   6770
# 4           Valby       60308   9.2            33917.0   4878
# 5         Vanløse       41195   6.7            33758.0   3915
# 3       Vesterbro       72688   8.2            41955.0   6710
# 1        Østerbro       79803   8.7            44743.0   7835

# %% [markdown]
# #### Shape files
# For a better visual seperation between the districts, shapefiles of the Copenhagen municipality are gathered from the following github-page:
# - https://github.com/codeforamerica/click_that_hood/blob/master/public/data/copenhagen.geojson

# %%
import urllib, geojson, gdal, subprocess
import geopandas as gpd # Import geopandas package


# Import shapefile from github:
url = 'https://raw.githubusercontent.com/codeforamerica/click_that_hood/master/public/data/copenhagen.geojson'
response = urllib.request.urlopen(url)
data = geojson.loads(response.read())

with open('data.geojson', 'w', encoding='utf-8') as f:
    geojson.dump(data, f)
    
args = ['ogr2ogr', '-f', 'ESRI Shapefile', 'destination_data.shp', 'data.geojson']
subprocess.Popen(args);

# Read in shapefile and examine data
df_cph = gpd.read_file('destination_data.shp')
df_cph = df_cph.drop(['id','cartodb_id','created_at','updated_at'],axis=1)
df_cph=df_cph.rename(columns={'name':'district'})
df_cph.loc[3,'district']='Vesterbro'
df_cph
# Out:
#    bydel_nr        district                                           geometry
# 0         1        Indre By  POLYGON ((12.611486 55.697631, 12.615337 55.69...
# 1         2        Østerbro  POLYGON ((12.615915 55.720652, 12.619998 55.72...
# 2         5           Valby  POLYGON ((12.524338 55.66666, 12.524491 55.666...
# 3         4       Vesterbro  POLYGON ((12.544458 55.640377, 12.544458 55.64...
# 4         9      Amager Øst  POLYGON ((12.630936 55.670503, 12.631257 55.67...
# 5         7  Brønshøj-Husum  POLYGON ((12.46894 55.699755, 12.466985 55.700...
# 6         3        Nørrebro  POLYGON ((12.561648 55.696674, 12.561521 55.69...
# 7         8      Bispebjerg  POLYGON ((12.515938 55.706643, 12.515394 55.70...
# 8         6         Vanløse  POLYGON ((12.46894 55.699755, 12.469353 55.699...
# 9        10     Amager Vest  POLYGON ((12.582711 55.668498, 12.586613 55.66...

# %% [markdown]
# All the districts that are of interest can now be illustrated with their geometry.

# %% [markdown]
# # Data analysis
#
# This section aims to explain what has been learned about the dataset. The section is divided between 'Barplot', 'Maps' and 'Stacked barchart'.

# %% [markdown]
# ## Barplots
#
# This section explores the dataframe ``df2``. The purpose of this is to see how the districts are different with regards to the amount of trees when taking the population, area and house prices per $m^2$ into account.
#
# Initially the four features ``trees``, ``area``, ``population``, ``Square meter price`` are plotted.

# %%
# Figure size
plt.rcParams['figure.figsize'] = (15, 8)

fig, axs = plt.subplots(2,2,sharex = 'col')
# Tree counts
axs[0,0].bar(df2['district'],df2['trees'])
axs[0,0].set_title("Tree counts")
axs[0,0].set_ylabel('Tree counts')
# Area 
axs[0,1].bar(df2['district'],df2['area'])
axs[0,1].set_title("Area")
axs[0,1].set_ylabel("km²")
# Population 
axs[1,0].bar(df2['district'],df2['population'])
axs[1,0].set_title("Population")
axs[1,0].set_ylabel("Citizens")
# Square meter prices
axs[1,1].bar(df2['district'],df2['squaremeter_price'])
axs[1,1].set_title('Square meter price')
axs[1,1].set_ylabel("[DKK/m²]")

axs[1,0].tick_params('x',labelrotation=45)
axs[1,1].tick_params('x',labelrotation=45)
plt.suptitle('Distrit features', size = 18)
plt.show()

# %% [markdown]
# The plot shows that Bispebjerg has the most amount of trees, closly followed by Østerbro while Amager Vest by far has the largest area in Copenhagen (important to remember that we are ONLY looking at street trees and park trees handled by the Copenhagen municipality). The districts with the largest population are Amager Vest, Nørrebro and Østerbro. The most expensive district measured by square meter price is Indre by, followed by the "bros" (Østerbro, Nørrebro and Vesterbro).
#
# The plots gives a nice overview of how the "situation" is in Copenhagen but it takes up a lot of space and can be somewhat confusing. There for bokeh can be used to visualize all four plots in one barplot. However, as the plots are all on different scales they need to be put on the same scale to allow comparison. Therefor the values in the barplot are changed to percentage as this will keep the ratio for the individual barplots but allow them to be illustrated together. Notice that the percentage for ``Population``, ``Area`` and ``Trees`` are directly understandable however for ``Squaremeter price`` there is no intuative meaning of the value. But it is needed for getting all for features in an equal scale for plotting.

# %%
# Population
df2['Population'] = (df2.population/sum(df2.population))*100
df2['Population'] = round(df2['Population'],1)
# Area
df2['Area'] = (df2.area/sum(df2.area))*100
df2['Area'] = round(df2['Area'],1)
# Square meter price
df2['Squaremeter price'] = (df2.squaremeter_price/sum(df2.squaremeter_price))*100
df2['Squaremeter price'] = round(df2['Squaremeter price'],1)
# Trees
df2['Trees'] = (df2.trees/sum(df2.trees))*100
df2['Trees'] = round(df2['Trees'],1)
df2
# Out:
#          district  population  area  squaremeter_price  trees  Population  \
# 9     Amager Vest       78973  19.2            38214.0   4477        12.6
# 8      Amager Øst       59803   9.1            38214.0   3930         9.5
# 7      Bispebjerg       55172   6.8            33426.0   8268         8.8
# 6  Brønshøj-Husum       44784   8.7            30030.0   4151         7.1
# 0        Indre By       55866   9.0            50388.0   6105         8.9
# 2        Nørrebro       80254   4.1            42763.0   6770        12.8
# 4           Valby       60308   9.2            33917.0   4878         9.6
# 5         Vanløse       41195   6.7            33758.0   3915         6.6
# 3       Vesterbro       72688   8.2            41955.0   6710        11.6
# 1        Østerbro       79803   8.7            44743.0   7835        12.7
#
#    Area  Squaremeter price  Trees
# 9  21.4                9.9    7.8
# 8  10.1                9.9    6.9
# 7   7.6                8.6   14.5
# ...

# %%
# Import packages for plotting with Bokeh
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.plotting import figure
from bokeh.io import output_notebook, show
from bokeh.models import Legend
from bokeh.palettes import all_palettes
output_notebook(resources=None, verbose=False, hide_banner=False, load_timeout=5000, notebook_type='jupyter')
from bokeh.models import ColumnDataSource, ranges, LabelSet, HoverTool
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4369">Loading BokehJS ...</span>
#     </div>

# %%
# Construct the figure
p = figure(x_range=df2.district,plot_height=400,plot_width=650,
           y_range= ranges.Range1d(start=0,end=25))

# remove the grid
p.xgrid.grid_line_color=None
p.ygrid.grid_line_color=None
# Make sure bars stat at 0
p.y_range.start = 0
# Rotate the x-labels
p.xaxis.major_label_orientation = 0.5
# Remove - y-axis
p.yaxis.visible = False
# Remove the toolbar
p.toolbar_location=None
# Remove the grey box around the plot
p.outline_line_color = None

colors = ['#C5D699','#99BC66','#578300','#344F00','#1b3512']
bar = {}
items = []
color = 0
features = ['Population','Area','Squaremeter price','Trees']
for indx,i in enumerate(features):
    bar[i] = p.vbar(x='district', top=i, source=df2, muted=False,
                   width= 0.8, color=colors[color])
    items.append((i,[bar[i]]))
    color+=1
# Define legend
legend = Legend(items=items,location=(0,50))
# Add the hover tools - different for each item
p.add_tools(HoverTool(renderers=[items[1][1][0]], tooltips = [('Area','@area{0.0} km² (@Area{0.0}%)')]))
p.add_tools(HoverTool(renderers=[items[0][1][0]], tooltips = [('Population','@population (@Population{0.0}%)')]))
p.add_tools(HoverTool(renderers=[items[2][1][0]], tooltips = [('Square meter price','@squaremeter_price DKK')]))
p.add_tools(HoverTool(renderers=[items[3][1][0]], tooltips = [('Trees','@trees (@Trees{0.0}%)')]))

# Set which bars to be invisible at the start
bar['Trees'].visible = False
bar['Squaremeter price'].visible = False
bar['Area'].visible = False

p.add_layout(legend,'left')
p.legend.click_policy='hide'
show(p)
# Out:
#   <div class="bk-root" id="aaee7a4d-de86-491c-acf4-d66da075f3e0" data-root-id="4371"></div>

# %% [markdown]
# In the bokeh plot all features are showed in one single plot which saves a lot of space. By adding a hover tool the viewer can see the specific values if he/she finds it interesting. To the left side it is possible to switch between the features. It is decided to use the ``click_policy= 'hide'`` as it is feared that the muting function might cause confusion to the viewer. With the ``hide`` policy it can however be hard to compare the features, but by clicking and unclicking the desired features it is possible to get an idea.
#
# To dig further into the analysis it is explored how the features look when factorizing by the amount of trees. To do this ratios are constructed for ``area``, ``population`` and ``squaremeter_price``:
# - ``areaRatio`` - amount of trees per $km^2$.
# - ``popRatio`` - trees per 100 citizens.
# - ``squaremeter_price``- trees per 1000 DKK $m^2$ price.

# %%
df2['popRatio'] = df2['trees']/(df2['population'])*100
df2['areaRatio'] = df2['trees']/df2['area']
df2['squaremeter_priceRatio'] = df2['trees']/(df2['squaremeter_price'])*1000
df2
# Out:
#          district  population  area  squaremeter_price  trees  Population  \
# 9     Amager Vest       78973  19.2            38214.0   4477        12.6
# 8      Amager Øst       59803   9.1            38214.0   3930         9.5
# 7      Bispebjerg       55172   6.8            33426.0   8268         8.8
# 6  Brønshøj-Husum       44784   8.7            30030.0   4151         7.1
# 0        Indre By       55866   9.0            50388.0   6105         8.9
# 2        Nørrebro       80254   4.1            42763.0   6770        12.8
# 4           Valby       60308   9.2            33917.0   4878         9.6
# 5         Vanløse       41195   6.7            33758.0   3915         6.6
# 3       Vesterbro       72688   8.2            41955.0   6710        11.6
# 1        Østerbro       79803   8.7            44743.0   7835        12.7
#
#    Area  Squaremeter price  Trees   popRatio    areaRatio  \
# 9  21.4                9.9    7.8   5.669026   233.177083
# ...

# %%
# Figure size
plt.rcParams['figure.figsize'] = (15, 8)

fig, axs = plt.subplots(2,2,sharex = 'col')
# Tree counts
axs[0,0].bar(df2['district'],df2['trees'])
axs[0,0].set_title("Tree counts")
axs[0,0].set_ylabel('Tree counts')
# Area ratio
axs[0,1].bar(df2['district'],df2['areaRatio'])
axs[0,1].set_title("Area ratio")
axs[0,1].set_ylabel("Trees per km²")
# Population ratio
axs[1,0].bar(df2['district'],df2['popRatio'])
axs[1,0].set_title("Population ratio")
axs[1,0].set_ylabel("Trees per 100 citizens")

# Income ratio
axs[1,1].bar(df2['district'],df2['squaremeter_priceRatio'])
axs[1,1].set_title('Square meter price ratio')
axs[1,1].set_ylabel("Trees per 1000 DKK m²")

axs[1,0].tick_params('x',labelrotation=45)
axs[1,1].tick_params('x',labelrotation=45)
plt.suptitle('Ratio plots', size = 18)
plt.show()

# %% [markdown]
# The plot shows that by factorizing in the trees the district with the most amount of trees per $km^2$ is Nørrebro. By inspecting the population ratio it can be seen that if having trees to yourself is important then Bispebjerg is preferable as there are more than 14 trees per every 100 citizens. If you are interested in getting as many trees to the lowest possible house price Bispebjerg is again prefered with 247 trees per 1000 DKK $m^2$ price.
#
# As each ratio is different it was decided that having all ratios in one plot as before might be confusing to the viewer. Therefor seperate plots are constructed for each ratio in bokeh.

# %%
######## Plot for popRatio ######## 
source1 = ColumnDataSource(data=dict(district=df2.district,
                                   popRatio=df2.popRatio,
                                   popRatioStr=round(df2.popRatio,1)))

# Figure
p1 = figure(x_range=df2.district,plot_height=300,plot_width=500,
           y_range= ranges.Range1d(start=0,end=17),
           title="Trees per 100 citizens")

# Same colorcodes used
colorcode_BBC = ['#C5D699','#99BC66','#578300','#344F00','#1b3512']
color = colorcode_BBC[0]

# Bar chart
p1.vbar(x='district',top='popRatio',source = df2,width=0.9,color=color)

# remove the grid
p1.xgrid.grid_line_color=None
p1.ygrid.grid_line_color=None
# Make sure bars stat at 0
p1.y_range.start = 0
# Turn the x-labels
p1.xaxis.major_label_orientation = 0.5
# remove - y-axis
p1.yaxis.visible = False
# Remove the toolbar
p1.toolbar_location=None
# Remove the grey box around the plot
p1.outline_line_color = None
# Move the border of the left side to show "Amager"
p1.min_border_left = 30

# add hover tool
p1.add_tools(HoverTool(tooltips = [('Trees pr. 100 citizens','@popRatio{0.0}')]))


######## Plot for areaRatio ######## 
source2 = ColumnDataSource(data=dict(district=df2.district,
                                   areaRatio=df2.areaRatio,
                                   areaRatioStr=round(df2.areaRatio,0)))

# Figure
p2 = figure(x_range=df2.district,plot_height=300,plot_width=500,
           y_range= ranges.Range1d(start=0,end=1800),
           title="Trees per km²")

color = colorcode_BBC[1]
# Bar chart
p2.vbar(x='district',top='areaRatio',source = df2,width=0.9,color=color)

# remove the grid
p2.xgrid.grid_line_color=None
p2.ygrid.grid_line_color=None
# Make sure bars stat at 0
p2.y_range.start = 0
# Turn the x-labels
p2.xaxis.major_label_orientation = 0.5
# remove - y-axis
p2.yaxis.visible = False
# Remove the toolbar
p2.toolbar_location=None
# Remove the grey box around the plot
p2.outline_line_color = None
# Move the border of the left side to show "Amager"
p2.min_border_left = 30

# add hover tool
p2.add_tools(HoverTool(tooltips = [('Trees pr. km²','@areaRatio{0.0}')]))

######## Plot for squaremeter_priceRatio ########
source2 = ColumnDataSource(data=dict(district=df2.district,
                                   squaremeter_priceRatio=df2.squaremeter_priceRatio,
                                   squaremeter_priceRatioStr=round(df2.squaremeter_priceRatio,0)))
color = colorcode_BBC[2]
# Figure
p3 = figure(x_range=df2.district,plot_height=300,plot_width=500,
           y_range= ranges.Range1d(start=0,end=300),
           title="Trees per 1000DKK m²")

# Bar chart
p3.vbar(x='district',top='squaremeter_priceRatio',source = df2,width=0.9,color=color)

# remove the grid
p3.xgrid.grid_line_color=None
p3.ygrid.grid_line_color=None
# Make sure bars stat at 0
p3.y_range.start = 0
# Turn the x-labels
p3.xaxis.major_label_orientation = 0.5
# remove - y-axis
p3.yaxis.visible = False
# Remove the toolbar
p3.toolbar_location=None
# Remove the grey box around the plot
p3.outline_line_color = None
# Move the border of the left side to show "Amager"
p3.min_border_left = 30

# add hover tool
p3.add_tools(HoverTool(tooltips = [('Trees per 1000DKK m²','@squaremeter_priceRatio{0.0}')]))

# %%
from bokeh.layouts import row
show(row(p1,p2))
show(p3)
# Out:
#   <div class="bk-root" id="082e183d-f277-4224-b0f3-214cf4771712" data-root-id="4946"></div>
#   <div class="bk-root" id="ba17effd-7ca9-4439-8eb2-87b80e5aa085" data-root-id="4908"></div>

# %% [markdown]
# In the plots a hovertool is again added for the viewer to gain acces to more detailed information on demand.
#
# Beneath the feature ``planteaar`` is explored.

# %%
temp=np.unique(df['planteaar'],return_counts = True) # Get unique years with counts

#Plot
sns.set(rc={'figure.figsize':(12,5)}) #Fig size
allyear= temp[0][0:len(temp[0])-1] # Take all years but besides 'not registered'
yeartemp = [float(i) for i in allyear] # Convert year to float
plt.plot(yeartemp,temp[1][0:len(temp[1])-1])
#plt.axvline(x=2012, color='red')
plt.xlabel("Year")
plt.ylabel("Trees planted")
plt.title("Trees planted pr. year")
plt.show()
print("Percentage of trees with a unregistered plant year:", round(temp[1][-1]/sum(temp[1])*100,0),"%")
# Out:
# Percentage of trees with a unregistered plant year: 45.0 %

# %% [markdown]
# The plot shows when the trees in the dataset are planted, however 45% of the trees do not have a registered plant year which should be taken into account. The graph shows that up until 1900 not many trees are being planted (or at least have a registered plant year) but in 1900 almost 1000 trees are planted. This could be a result of the rapid expansion that happened in Copenhagen in the late 1800 with Amager, Vanløse and Husum/Brønshøj. Here after trees are regularly planted and the amount steadily increases by each year and peaks with more than 3000 trees in 2012. This plot is not added to the final webpage as it was found that eventhough it is interesting it would not add anything new to the story. However, the graph was used extensive for understanding the data.
#
# To see which districts have been invested in with regards to tree, the trees which have been planted from 2010 to 2020 are illustrated below in Bokeh.

# %%
years = set(['2010.0','2011.0','2012.0','2013.0','2014.0',
             '2015.0','2016.0','2017.0','2018.0','2019.0','2020.0'])

temp = df[df['planteaar'].isin(years)] # Choosen only the selected years
byDis = temp.groupby(['bydelsnavn']).count()['id'] # Group by the district
temp = pd.DataFrame(columns=['district','trees'])
temp['district'] = byDis.index
temp['trees'] = byDis.values
temp = temp.sort_values('trees',ascending=True)

source = ColumnDataSource(data=dict(district=temp.district,
                                   trees=temp.trees))

## Make the figure
colorcode_BBC = ['#C5D699','#99BC66','#578300','#344F00','#1b3512']
color = colorcode_BBC[2]

p = figure(y_range=temp['district'], plot_height = 300,
          plot_width=700,x_range=ranges.Range1d(start=0,end=3550))
p.hbar(y='district',right='trees', source=temp, height=0.8,color=color)

# remove the grid
p.xgrid.grid_line_color=None
p.ygrid.grid_line_color=None
# Make sure bars stat at 0
p.x_range.start = 0
# remove - y-axis
p.xaxis.visible = False
# Remove the toolbar
p.toolbar_location=None
# Remove the grey box around the plot
p.outline_line_color = None

# add labels
labels = LabelSet(y='district',x='trees',text='trees',level='glyph',
                  x_offset=3,y_offset=-10,text_font_size="14pt",
                  source=source)
p.add_layout(labels)

show(p)
# Out:
#   <div class="bk-root" id="ea9c51b7-7b01-45ea-8a84-27c535bb5f1f" data-root-id="3017"></div>

# %% [markdown]
# The biggest investment for the municipality of Copenhagen over the last 10 year have been in the district Østerbro. Almost double the amount is planted here than in Valby which is at a second place, and 10 times more than Brønshøj-Husum at the bottom. This can be due to the rapid developmentprojects of the streets and areas around Østerbro. As well as an increased awareness of the benifits that street- and park trees are contributing to the surounding neighbourhood. This can be investigated further with a map of the individual trees which is illustrated further down. In the map try forexample to find the newly developed areas a bit north of Fælledparken namely Tåsing plads and Sankt Kjelds Plads. In the plot numbers are added to give the user a quick overview and to change the layout of the plots, a hovertool is therefor not added.

# %% [markdown]
# ## Maps
#
# This section explores the dataframes ``df_cph`` and ``df``. The purpose of this is to visualize how the trees are distributed across the municiplality of Copenhagen by using Bokeh.
#
# Initially a map of the districts is produced.

# %%
# Merge population, area and number of trees together with shapefiles
temp = pd.merge(df_cph,df2,on='district')

# Add the procentage for all features in every neighbouhood
p_population =  temp['population']/sum(temp['population'])*100
temp['p_population']=p_population
p_area = temp['area']/sum(temp['area'])*100
temp['p_area']=p_area
p_trees = temp['trees']/sum(temp['trees'])*100
temp['p_trees']=p_trees

df_cph = temp
df_cph
# Out:
#    bydel_nr        district  \
# 0         1        Indre By
# 1         2        Østerbro
# 2         5           Valby
# 3         4       Vesterbro
# 4         9      Amager Øst
# 5         7  Brønshøj-Husum
# 6         3        Nørrebro
# 7         8      Bispebjerg
# 8         6         Vanløse
# 9        10     Amager Vest
#
#                                             geometry  population  area  \
# 0  POLYGON ((12.611486 55.697631, 12.615337 55.69...       55866   9.0
# 1  POLYGON ((12.615915 55.720652, 12.619998 55.72...       79803   8.7
# 2  POLYGON ((12.524338 55.66666, 12.524491 55.666...       60308   9.2
# 3  POLYGON ((12.544458 55.640377, 12.544458 55.64...       72688   8.2
# 4  POLYGON ((12.630936 55.670503, 12.631257 55.67...       59803   9.1
# 5  POLYGON ((12.46894 55.699755, 12.466985 55.700...       44784   8.7
# 6  POLYGON ((12.561648 55.696674, 12.561521 55.69...       80254   4.1
# 7  POLYGON ((12.515938 55.706643, 12.515394 55.70...       55172   6.8
# ...

# %% [markdown]
# The dataframe can now be convert to a format that is conducive to mapping.

# %%
from bokeh.models import GeoJSONDataSource
import json

# Input GeoJSON source that contains features for plotting
geosource = GeoJSONDataSource(geojson = df_cph.to_json())

# %% [markdown]
# A colorbar is defined, the intencity of the colorbar illustrates the amount of trees in a district.

# %%
from bokeh.models import (LinearColorMapper, ColorBar)
# Specify the colorcodes
colorcode_BBC = ['#C5D699','#99BC66','#578300','#344F00','#1b3512']

# Transform it to a color map
color_mapper2 = LinearColorMapper(palette = colorcode_BBC, low = 3000, high = 8000)

# Define custom tick labels for color bar.
tick_labels = {#'0': '0', '1000': '1000','2000':'2000',
 '3000':'3000',
 '4000':'4000', '5000':'5000','6000':'6000','7000':'7000','8000':'8000+'}

# Create color bar.
color_bar2 = ColorBar(color_mapper = color_mapper2, 
                     label_standoff = 8,
                     width = 750, height = 20,
                     border_line_color = None,
                     location = (0,0), 
                     orientation = 'horizontal',
                     major_label_overrides = tick_labels)

# Create figure object.
p = figure(title = 'Trees in the Copenhagen municipality',
           title_location = 'above',
           plot_height = 800 ,
           plot_width = 800, 
           toolbar_location = 'above',
           tools = 'pan, wheel_zoom, box_zoom, reset',
           aspect_scale=0.05)

# Change font size on title
p.title.text_font_size = '20pt'

p.axis.visible = False
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None

# Add patch renderer to figure.
neighbourhoods = p.patches('xs','ys', source = geosource,
                   fill_color = {'field' :'trees',
                                 'transform' : color_mapper2},
                   line_color = 'black', 
                   line_width = 0.75, 
                   fill_alpha = 1)

# Create hover tool
p.add_tools(HoverTool(renderers = [neighbourhoods],
                      tooltips = [('Neighbourhood','@district'),
                                 ('Population',' @population (@p_population{0.0}%)'),
                                 ('Trees','@trees (@p_trees{0.0}%)'),
                                 ('Area','@area{0.0} km² (@p_area{0.0}%)')]))

# Add colorbar 
p.add_layout(color_bar2, 'below')

# Remove bokeh logo
p.toolbar.logo = None

# Remove the grey box around the plot
p.outline_line_color = None

show(p)
# Out:
#   <div class="bk-root" id="76f701c7-142a-419e-9666-ded2deb19ac7" data-root-id="3505"></div>

# %% [markdown]
# The map gives a nice overview first of all of Copenhagen and the different districts and the sizes. The maps reveals that the district with most trees are Bispebjerg and Østerbro. By using the hovertool much more information can be seen about the district. Here the information used for plots earlier about the population, area and average square meter price is also available on demand.
#
# Beneath every tree observation with spacial data and tree type is explored. First the desired colors for every tree type are decided. The colormap used will be checked before use. It is important that the colors are easy to distinguish between eachother.

# %%
from colorcet.plotting import swatch, swatches
import holoviews as hv
hv.extension('matplotlib')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-113-b280a82bc110> in <module>
# ----> 1 from colorcet.plotting import swatch, swatches
#       2 import holoviews as hv
#       3 hv.extension('matplotlib')
#
# C:\Anaconda\lib\site-packages\colorcet\plotting.py in <module>
#       6
#       7 import numpy as np
# ----> 8 import holoviews as hv
#       9 from holoviews import opts
#      10
#
# ModuleNotFoundError: No module named 'holoviews'

# %%
import colorcet as cc

# %% [markdown]
# The colormap was found by inspecting different colormaps from the following website
# - https://colorcet.holoviz.org/user_guide/index.html <br>
# The colorstrip printet  is the palette used for plotting.

# %% [markdown]
# Check colormap before using it:
# > Before we can see which colormap we have selected we need to install the folowing. Here I'm using pip, but it can also be installed by conda:
# >
# >  * git clone git://github.com/pyviz/holoviews.git
# >  * cd holoviews
# >  * pip install -e .
#
# # SKAL DET HER MED? ^

# %%
# Used colormap
swatch('glasbey_light')

# %% [markdown]
# For plotting the trees needs to be showed in alphabetic order. However, to find the best color combination, the trees are first sorted by the amount of trees.

# %%
# Trees ordered by amount of trees
focustrees = ['Not registered', 'Linden', 'Plane', 'Cherry/Plum', 'Rowan', 'Maple',
       'Ash', 'Oak', 'Black locust', 'Horse chestnut', 'Birch', 'Poplar',
       'Apple', 'Hawthorn', 'Hornbeam', 'Pine', 'Elm', 'Willow', 'Alder',
       'Minority trees', 'Hazel', 'Honey locust', 'Spruce', 'Pear', 'Thuja',
       'Dawn redwood', 'Yew', 'Tree of heaven', 'Beech', 'Gingko',
       'Tulip tree', 'Sweetgum', 'False cypress', 'Juneberry', 'Larch',
       'Magnolia', 'Chestnut', 'Golden rain', 'Cornus', 'Cedar', 'Walnut']

palette = cc.glasbey_light[1:len(df['slaegtsnavn_eng'].unique())*2+1] # Best so far
dict_colors={}
list_colors=[]
for index,i in enumerate(focustrees):
    dict_colors[i]=palette[index*2]
    list_colors.append(palette[index*2])

# %% [markdown]
# By inspection it is found that the color for the ``False cypress`` and ``Cornus`` was insufficient (too white), these colors are therefor changed.

# %%
dict_colors.update({'False cypress':'#a77b87','Cornus':'#7ea59a'})

# %% [markdown]
# Now that the trees have got a corresponding color, they are sorted by alphabetic order.

# %%
from collections import OrderedDict
# Sort color dictionary by alphabet
dict_colors=OrderedDict(sorted(dict_colors.items(), key=lambda t: t[0]))

list_colors=list(dict_colors.values())
focustrees=list(sorted(focustrees))

# %% [markdown]
# # Kan vi få et par kommentarer på koden over? Hvad gør vi her? :-)

# %% [markdown]
# The district shapes need to be transformed from latitude and longitude coordinates to UTM coordinates, to plot them together with the desired background map.

# %%
import pyproj

# %%
# Creating the geoDataFrame and set it to its initial coordinate codes
geo_df_cph = gpd.GeoDataFrame(df_cph[['district']], geometry=df_cph['geometry'])
geo_df_cph.crs = {'init': 'epsg:4326'}

# Transform to wgs84 UTM32
geo_df_cph = geo_df_cph.to_crs({'init': 'epsg:3857'})

# The new GeoDataSource is generated
geosource = GeoJSONDataSource(geojson = geo_df_cph.to_json())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-130-76dc3cd8372b> in <module>
#       4
#       5 # Transform to wgs84 UTM32
# ----> 6 geo_df_cph = geo_df_cph.to_crs({'init': 'epsg:3857'})
#       7 #geo_df_cph = geo_df_cph.to_crs(epsg=3857)
#       8
#
# C:\Anaconda\lib\site-packages\geopandas\geodataframe.py in to_crs(self, crs, epsg, inplace)
#     441         else:
#     442             df = self.copy()
# --> 443         geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#     444         df.geometry = geom
#     445         df.crs = geom.crs
#
# C:\Anaconda\lib\site-packages\geopandas\geoseries.py in to_crs(self, crs, epsg)
#     302             except TypeError:
#     303                 raise TypeError('Must set either crs or epsg for output.')
# --> 304         proj_in = pyproj.Proj(self.crs, preserve_units=True)
# ...

# %% [markdown]
# The same transformation of the coordinates needs to be done for every observation, therefor the function ``merc(X,Y)`` is constructed which takes latitude and longitude and transform to UTM coordinates.

# %%
import math
from ast import literal_eval

# Define a function that can transform coordinates from latitude and longitude to UTM coordinates
def merc(X,Y):
    lat = Y
    lon = X
    
    r_major = 6378137.000
    x = r_major * math.radians(lon)
    scale = x/lon
    y = 180.0/math.pi * math.log(math.tan(math.pi/4.0 + 
        lat * (math.pi/180.0)/2.0)) * scale
    return (x, y)

# %%
# Initialize columns
df['X_merc']=np.zeros(len(df))
df['Y_merc']=np.zeros(len(df))

# Loop over all trees and calculate the respective coordinates
for i in range(len(df)):
    # Transforming to UTM coordinates
    temp1 = merc(df.loc[i,'X'],df.loc[i,'Y'])
    df.loc[i,'X_merc'] = temp1[0]
    df.loc[i,'Y_merc'] = temp1[1]

# %% [markdown]
# With the coordinates all the trees can now be plotted for Copenhagen. To make it easy to navigate the location of the trees a background map is added. The outline of the districts are further added.

# %%
from bokeh.tile_providers import CARTODBPOSITRON, get_provider
import bokeh.models as bmo
from bokeh.models import BoxZoomTool

# Create figure object.
p1 = figure(title = 'Trees in Copenhagen', 
           plot_height = 700 ,
           plot_width = 1000, 
           toolbar_location = 'below',
           tools = 'pan, reset',
           match_aspect=True,
           #aspect_ratio=1,
           aspect_scale=0.05,
           x_range=(1388028.66, 1407078.36), y_range=(7481600.35,7505852.98),
           x_axis_type="mercator", y_axis_type="mercator")

# Plot the map of Copenhagen as our background
tile_provider = get_provider(CARTODBPOSITRON)
p1.add_tile(tile_provider)

# Change font size on title
p1.title.text_font_size = '20pt'

p1.axis.visible = False
p1.xgrid.grid_line_color = None
p1.ygrid.grid_line_color = None

p1.min_border_top = 0
p1.min_border_bottom = 0

# Add patch renderer to figure.
p1.patches('xs','ys', source = geosource,
                   line_color = 'black', 
                   line_width = 2 
                   ,fill_alpha = 0)

# Create the circles of every tree type
circle = {}
items=[]
for index,i in enumerate(focustrees):
    temp1=df[df['slaegtsnavn_eng']==i]
    treesource = ColumnDataSource(temp1)
    circle[i]= p1.circle(x='X_merc'
              ,y='Y_merc'
              ,source=treesource
              ,legend_label= i 
              ,color=dict_colors[i]
              ,radius=11
              ,line_alpha=0.9
              ,fill_alpha=0.2
              ,name='needshover')
    items.append((i,[circle[i]]))

# Fix BoxZoomTool to only allow to zoom with squares 
p1.add_tools(BoxZoomTool(match_aspect=True))

# Add hover tool
p1.add_tools(HoverTool(names=['needshover']
                       ,tooltips = [('Neighbourhood','@bydelsnavn')
                                   ,('Location (Lat,Lon)', '(@Y,@X)')
                                   ,('Tree type', '@slaegtsnavn_eng')
                                   ,('Planting year','@planteaar{0}')]
                                  ))

# Remove the grey box around the plot
p1.outline_line_color = None

# Remove bokeh logo in tools
p1.toolbar.logo = None

# Set legends 
legend1 = Legend(items=items[:21], location=(10, 60), click_policy="hide") 
legend2 = Legend(items=items[21:], location=(10, 83.5), click_policy="hide") 
                # assigns the click policy (you can try to use 'hide'

# Remove original legends and add them to the right of the plot
p1.legend.visible = False
p1.add_layout(legend1, 'right')
p1.add_layout(legend2, 'right')

# Specify layout
show(p1)

# %% [markdown]
# It can be seen in the map above that the vast majority of the trees are corresponding to the category **Not registered** trees which mean that the tree type has not been identified (indicated with green circles). Try to remove these from the map an get an better indication of the known tree types in Copenhagen. In the map it becomes very clear that the parks such as 'Botanisk have', 'Kongens have' and 'Kalvebod Fælled' are not a part of the dataset. With the map it is possible to discover the trees close to your neighborhood or any where which if of iterest. Again a hover tool is added for more intormation on demand.

# %% [markdown]
# ### Interesting maps
# This section looks into visualizing different aspects of the dataset through the use of maps. The idea is that the features should add a different aspect to the trees and maybe even be an inspiration for a walk through out the city to see the trees in real life.
#
# #### Most lonely tree
# The most lonely tree is displayed as a fun feature. The most lonely tree is categorized as the tree which is positioned longest away from another tree. The function ``dist_point`` is created to find the tree that is the most lonely. The distance is found in meters.

# %%
import pyproj
geod = pyproj.Geod(ellps='WGS84')

def dist_point(X,Y):
    alltimebest = 0
    for X_iP1,Y_iP1 in zip(enumerate(X),enumerate(Y)):
        nearest = 100000
        for X_iP2,Y_iP2 in zip(enumerate(X),enumerate(Y)):
            if X_iP1[0] != X_iP2[0]:
                angle1,angle2,distance = geod.inv(X_iP1[1], Y_iP1[1],X_iP2[1], Y_iP2[1])
                if distance < nearest:
                    nearest = distance
                    index_nearest = X_iP2[0]
                if alltimebest > nearest:
                    break
        if nearest > alltimebest:
            alltimebest = nearest
            index_trees = [X.index[X_iP1[0]],X.index[index_nearest]]
    return alltimebest,index_trees

# %% [markdown]
# As it takes app. 50 minutes to evaluate all trees and their distance to the nearest neighbour the code below is commented out and the results are showed below. The most lonely tree is found to be placed on an outer boundary in the district of Bispebjerg with a distance of 255.2m to the nearest neighbour. This will probably not be the most lonely, as it could have close neighbours outside the Copenhagen municipality. The second most lonely tree is therefor identified, the tree is positioned at the inner boundary of Amagervest with 231.4 m to the nearest neighbour.

# %%
#import time
#start_time = time.time()
## Finding the most lonely tree in Cph
#alltimebest,index_trees = dist_point(df.X,df.Y)
#print("--- %s seconds ---" % (time.time() - start_time))
#print(alltimebest,index_trees)

# %% [markdown]
# |  | Time | Position | Distance to nearest neighbour |
# | --- |--- | --- | ---|
# | Most lonely tree | 63 min | Ourter boundary of Bispebjerg | 255.2 m |
# | Second most lonely tree | 60 min | Inner boundary of Amager Vest | 231.4 m |

# %% [markdown]
# Below the two identified trees are plotted on the map.

# %%
# Create figure object.
pL = figure(title = 'The most lonely trees and their nearest neighbour', 
           plot_height = 900 ,
           plot_width = 900, 
           toolbar_location = 'below',
           tools = 'pan, reset',
           match_aspect=True,
           x_range=(1388028.66, 1407078.36), y_range=(7481600.35,7505852.98),
           x_axis_type="mercator", y_axis_type="mercator")

# Change font size on title
pL.title.text_font_size = '20pt'

pL.axis.visible = False
pL.xgrid.grid_line_color = None
pL.ygrid.grid_line_color = None

# Plot the map of Copenhagen as our background
tile_provider = get_provider(CARTODBPOSITRON)
pL.add_tile(tile_provider)

# Add patch renderer to figure.
neighbourhoods = pL.patches('xs','ys', source = geosource,
                   line_color = 'black', 
                   line_width = 2, 
                   fill_alpha = 0)

# Draw all tree 
pL.circle(x=df['X_merc'], y=df['Y_merc'],
           color='#018700',radius=8 
           ,line_alpha=0.8
           ,fill_alpha=0.1)

# Draw the most lonely and its neatest neighbour
circleLB = pL.circle(x=df['X_merc'][16401], y=df['Y_merc'][16401],
           color='red',size=14
           , line_alpha=0.9
              ,fill_alpha=0.3)
pL.circle(x=df['X_merc'][2562], y=df['Y_merc'][2562],
           color='orange',size=10
           , line_alpha=0.8
              ,fill_alpha=0.2)

# Draw the second most lonely and its nearest neighbour
circleLnotB = pL.circle(x=df['X_merc'][16467], y=df['Y_merc'][16467],
           color='blue',size=14
           , line_alpha=0.9
              ,fill_alpha=0.3)
pL.circle(x=df['X_merc'][16462], y=df['Y_merc'][16462],
           color='orange',size=10
           , line_alpha=0.8
              ,fill_alpha=0.2)

pL.toolbar.logo = None

# Create hover tools for the two most lonely trees
pL.add_tools(HoverTool(renderers = [circleLB],
                      tooltips = [('Neighbourhood','Bispebjerg') #Hardcoded neighbourhood..
                                 ,('Distance to its nearest neighbour (orange tree)','249.1 meters')]))
pL.add_tools(HoverTool(renderers = [circleLnotB],
                      tooltips = [('Neighbourhood','Amager Vest') #Hardcoded neighbourhood..
                                 ,('Distance to its nearest neighbour (orange tree)','231.4 meters')]))

# Zoom only in squares
pL.add_tools(BoxZoomTool(match_aspect=True))

# Remove the grey box around the plot
pL.outline_line_color = None

show(pL)

# %% [markdown]
# #### Oldest trees
# This section looks into finding some of the oldest trees in Copenhagen and visualizing them using a map. Lets first recall the different planting years.

# %%
df['planteaar'].unique()

# %% [markdown]
# Again the label 'Not registered' is observed which earlier was found to be true for 41% of the trees. However, the list also reveals planting years as far back as 1773.

# %%
# Sort planting year after oldest trees
temp_old = df.groupby(['planteaar']).size()
temp_old=pd.DataFrame(temp_old)
temp_old=temp_old.rename(columns={0:'Amount'})
temp_old=temp_old.sort_index(ascending=True)
temp_old.iloc[:11]

# %% [markdown]
# To avoid having too many labels on the plot it is decided to focus on only the oldest trees before 1900. Below these are plotted.

# %%
# Planting year in focus
focus_old=set(['1773.0','1850.0','1860.0','1880.0','1886.0','1890.0','1891.0','1892.0','1895.0','1899.0','1900.0'])
focus_old_list=[1773.0,1850.0,1860.0,1880.0,1886.0,1890.0,1891.0,1892.0,1895.0,1899.0,1900.0]
focus_old_name=['Year 1773','Year 1850', 'Year 1860','Year 1880','Year 1886','Year 1890','Year 1891','Year 1892','Year 1895','Year 1899','Year 1900']

# DataSource for tree planted later than 1900
tempO=df.loc[~df['planteaar'].isin(focus_old)]
old2source = ColumnDataSource(tempO)

# %%
# Create figure object.
pO = figure(title = 'Oldest trees in Copenhagen', 
           plot_height = 900 ,
           plot_width = 900, 
           toolbar_location = 'below',
           tools = 'pan, reset',
           match_aspect=True,
           x_range=(1388028.66, 1407078.36), y_range=(7481600.35,7505852.98),
           x_axis_type="mercator", y_axis_type="mercator")


# Plot the map of Copenhagen as our background
tile_provider = get_provider(CARTODBPOSITRON)
pO.add_tile(tile_provider)

# Change font size on title
pO.title.text_font_size = '20pt'

pO.axis.visible = False
pO.xgrid.grid_line_color = None
pO.ygrid.grid_line_color = None

pO.min_border_top = 0
pO.min_border_bottom = 0

# Add patch renderer to figure.
pO.patches('xs','ys', source = geosource,
                   line_color = 'black', 
                   line_width = 2 
                   ,fill_alpha = 0)

# Draw the coordinates as circles
Others=pO.circle(x='X_merc', y='Y_merc', source=old2source,legend_label= 'Rest',
           color='#018700', radius=8, line_alpha=0.7,fill_alpha=0.1)

# Create the circles with its hover
circle = {}
items=[]

for index,i in enumerate(focus_old_list):
    tempOld=df[df['planteaar']==str(i)]
    oldsource = ColumnDataSource(tempOld)
    circle[i]= pO.circle(x='X_merc'
              ,y='Y_merc'
              ,source=oldsource
              ,legend_label= focus_old_name[index] 
              ,color=palette[index+1]
              #,radius=50
              ,size=8
              ,line_alpha=1
              ,fill_alpha=0.5
              ,name='needshover')
    items.append((focus_old_name[index],[circle[i]]))



# Set as non visuabel by default
circle[1900.0].visible = False
Others.visible = False


items.append(('Other',[Others]))

# Create hover tool
pO.add_tools(HoverTool(names = ['needshover']
                      ,tooltips = [('Neighbourhood','@bydelsnavn')
                                  ,('Location (Lat,Lon)', '(@Y,@X)')
                                  ,('Tree type', '@slaegtsnavn_eng')
                                  ,('Planting year','@planteaar{0}')]))


# Remove the grey box around the plot
pO.outline_line_color = None

# Zoom only in squares
pO.add_tools(BoxZoomTool(match_aspect=True))

pO.toolbar.logo = None

legendOld = Legend(items=items, click_policy="hide")  
                # assigns the click policy (you can try to use ''hide'


pO.legend.visible = False
pO.add_layout(legendOld, 'right')

show(pO)

# %% [markdown]
# The map reveals where the oldest trees of Copenhagen are placed. Try to add the trees planted in year 1900, and see how many that was planted the given year. The trees that are planted after 1900 can also be displayed on the map to get an idea of how many trees have emerged since.

# %% [markdown]
# #### Donor
# Some of the trees have been donated to the muncipalicity by different organisations which will be displayed in this section.

# %%
# Groupby the feature donor
temp_group5 = df.groupby(['donor']).size()
temp_group5=pd.DataFrame(temp_group5)
temp_group5=temp_group5.rename(columns={0:'Antal'})
temp_group5=temp_group5.sort_index(ascending=True)
temp_group5

# %% [markdown]
# As it can the seen the vast majority of trees are not donated. In the following the focus will be only the trees which are donated.

# %%
focus_donor=['The Adventurers’ Club of Denmark',
       'Jf Peder Clement, received from Ålholm Arboret',
       'The journalist association, American Red Wood Association',
       'SITAS nursery', 'FTM', 'Collection in England and Denmark',
       'Danish society in Austria w. Barbara Kauders',
       'Horticultural Farms Marketing Committee',
       'The Association for the beutification of the capital',
       'The Danish Society for Nature Conservation',
       'Jugendaustauschwerk im Kreis Gütersloh E.V.',
       'The Macedonian Embassy',
       'Tokyo by v. Dr.Ryotaro Azuma, Governor of Tokyo',
       'Guangzhou International Award for Urban Innovation',
       'Valby Rotary Club', 'Plant a tree', 'Lions Club',
       'Royal Danish Academy of Fine Arts', 'DSB']

# %%
from bokeh.models import RadioButtonGroup

# Create figure object.
pD = figure(title = 'Donor trees in Copenhagen', 
           plot_height = 800 ,
           plot_width = 1000, 
           toolbar_location = 'below',
           tools = 'pan, reset',
           match_aspect=True,
           x_range=(1386028.66, 1408578.36), y_range=(7481600.35,7505852.98),
           x_axis_type="mercator", y_axis_type="mercator")


# Plot the map of Copenhagen as our background
tile_provider = get_provider(CARTODBPOSITRON)
pD.add_tile(tile_provider)

# Change font size on title
pD.title.text_font_size = '20pt'

pD.axis.visible = False
pD.xgrid.grid_line_color = None
pD.ygrid.grid_line_color = None

# Add patch renderer to figure.
pD.patches('xs','ys', source = geosource,
                   line_color = 'black', 
                   line_width = 2 
                   ,fill_alpha = 0)

# Create the circles with its hover
circle = {}
itemsD=[]

for index,i in enumerate(focus_donor):
    temp5=df[df['donor']==i]
    oldsource = ColumnDataSource(temp5)
    circle[i]= pD.circle(x='X_merc'
              ,y='Y_merc'
              ,source=oldsource
              ,legend_label= focus_donor[index] 
              ,color=palette[index+1]
              ,size=8
              ,line_alpha=1
              ,fill_alpha=0.5
              ,name='needshoverS')
    itemsD.append((focus_donor[index],[circle[i]]))

# Create hover tool
pD.add_tools(HoverTool(names = ['needshoverS']
                      ,tooltips = [('Neighbourhood','@bydelsnavn')
                                  ,('Location (Lat,Lon)', '(@Y,@X)')
                                  ,('Tree type', '@slaegtsnavn_eng')
                                  ,('Plant year','@planteaar{0}')
                                  ]))

# Remove the grey box around the plot
pD.outline_line_color = None

# Zoom only in squares
pD.add_tools(BoxZoomTool(match_aspect=True))

pD.toolbar.logo = None

legendOld = Legend(items=itemsD, click_policy="hide", title='Donor trees:') 

pD.legend.visible = False
pD.add_layout(legendOld, 'right')

show(pD)

# %% [markdown]
# The map reveals where all donation trees are allocated.

# %% [markdown]
# #### Special features (tree history, private owned and botanic interest)
# The following three features: ``trae_historie``, ``ejer``and ``botanisk_interesse`` will be investigated at the same time.
# # VI BLIVER NØDT TIL AT FORTÆLLE LIDT OM DE HER FEATURES... HVORFOR GIVER DE MENING OG PLOTTE DEM SAMMEN OG HVAD BETYDER HVER FEATURE?

# %%
# Groupby tree history, and its different categories are displayed 
temp_group3 = df.groupby(['trae_historie']).size()
temp_group3=pd.DataFrame(temp_group3)
temp_group3=temp_group3.rename(columns={0:'Antal'})
temp_group3=temp_group3.sort_index(ascending=True)
temp_group3

# %%
# Making a dictionary for the trees we want in the different categories
dict_all_new = {'Trees with privat owner':df[df['ejer']== 'Private']
                ,'Trees of botanical interest':df[df['botanisk_interesse']== 'Yes']
                ,'Trees w. hist: Protected through voluntary agreement':df[df['trae_historie']== 'Protected through voluntary agreement']
                ,'Trees w. hist: Honor tree':df[df['trae_historie']== 'Honor tree']
                ,'Trees w. hist: Donation tree':df[df['trae_historie']== 'Donation tree']
                ,'Trees w. hist: Cultural historical':df[df['trae_historie']== 'Cultural historical']}

# %%
# Create figure object.
pALL = figure(title = 'Special feature trees in Copenhagen', 
           plot_height = 700 ,
           plot_width = 1000, 
           toolbar_location = 'below',
           tools = 'pan, reset',
           match_aspect=True,
           x_range=(1386028.66, 1408578.36), y_range=(7481600.35,7505852.98),
           x_axis_type="mercator", y_axis_type="mercator")


# Plot the map of Copenhagen as our background
tile_provider = get_provider(CARTODBPOSITRON)
pALL.add_tile(tile_provider)

# Change font size on title
pALL.title.text_font_size = '20pt'

pALL.axis.visible = False
pALL.xgrid.grid_line_color = None
pALL.ygrid.grid_line_color = None

# Add patch renderer to figure.
pALL.patches('xs','ys', source = geosource,
                   line_color = 'black', 
                   line_width = 2 
                   ,fill_alpha = 0)

# Create the circles with its hover
circle = {}
items=[]

for index,i in enumerate(dict_all_new):
    tempALL=dict_all_new[i]
    oldsource = ColumnDataSource(tempALL)
    circle[i]= pALL.circle(x='X_merc'
              ,y='Y_merc'
              ,source=oldsource
              ,legend_label= i
              ,color=palette[index+2]
              ,size=8
              ,line_alpha=1
              ,fill_alpha=0.4
              ,name='needshover')
    items.append((i,[circle[i]]))

# Create hover tool
pALL.add_tools(HoverTool(names = ['needshover']
                      ,tooltips = [('Neighbourhood','@bydelsnavn')
                                  ,('Location (Lat,Lon)', '(@Y,@X)')
                                  ,('Tree type', '@slaegtsnavn_eng')
                                  ,('Planting year','@planteaar{0}')
                                  ]))

# Remove the grey box around the plot
pALL.outline_line_color = None

# Zoom only in squares
pALL.add_tools(BoxZoomTool(match_aspect=True))

pALL.toolbar.logo = None

legendSpecial = Legend(items=items, click_policy="hide", title='Special trees:')
                # assigns the click policy (you can try to use ''hide'


pALL.legend.visible = False
pALL.add_layout(legendSpecial, 'right')
show(pALL)

# %% [markdown]
# Notice that some of these trees are within serveral categories.
#
# Trees owned by TMF (Teknisk miljø forvaltning) or KK (Københavns Kommune) are not in the plot. As well as trees that are within the category **Not registered** are not taking into account when plotting, that would only interfere the illustration and the story.
# # SKAL UDDYBES! :)

# %% [markdown]
# ## Stackedbar chart
# As an extension to the map for all tree types a stackedbard chart is constructed to show the distrubtion of all tree types for the different districts. A dataframe containing the counts for each tree type is saved in ``temp``, as not all tree types are present in all districts the ``NaN`` values are filled with 0.

# %%
temp = df.groupby(['bydelsnavn','slaegtsnavn_eng']).count().id.unstack()
temp = temp.fillna(0) # some city areas do not have certain trees
temp = temp.reset_index()
temp
# Out:
# slaegtsnavn_eng      bydelsnavn  Alder  Apple    Ash  Beech  Birch  \
# 0                   Amager Vest   53.0   94.0  173.0    0.0    6.0
# 1                    Amager Øst   21.0  109.0  222.0    1.0  280.0
# 2                    Bispebjerg    1.0  115.0  310.0   29.0  209.0
# 3                Brønshøj-Husum   10.0   12.0  128.0    1.0  109.0
# 4                      Indre By    4.0   22.0   59.0    0.0    5.0
# 5                      Nørrebro    2.0   81.0  163.0    4.0  100.0
# 6                         Valby    3.0   41.0  417.0    3.0    6.0
# 7                       Vanløse   44.0    3.0  131.0    2.0   11.0
# 8                     Vesterbro   46.0  132.0  128.0    4.0   56.0
# 9                      Østerbro   59.0   51.0  223.0   34.0    8.0
#
# slaegtsnavn_eng  Black locust  Cedar  Cherry/Plum  Chestnut  Cornus  \
# 0                       238.0    0.0        215.0       0.0     0.0
# 1                        50.0    2.0        187.0       0.0     7.0
# ...

# %% [markdown]
# To add more information a column specifying how many percentages the tree type for a district is out of the total amount of that tree types, ``treeName_p`` as well as a column specifying how many percentages a tree type is out of all the trees for a district ``treeName_d``.

# %%
treeName = temp.columns.values[1:] # Define all the tree names

# Add the percentages for tree X out of all X trees
for tree in treeName:
    temp2 = []
    for values in temp[tree]:
        temp2.append(round(values/sum(temp[tree])*100,1))
        colName = "{}_p".format(tree)
    temp[colName] = temp2

# Add the percentages for tree X out of district Y
for tree in treeName:
    temp3 = []
    for i in range(temp.shape[0]):
        temp3.append(round((temp.iloc[i,:][tree]/sum(temp.iloc[i,:][treeName]))*100,1))
        colName = "{}_d".format(tree)
    temp[colName] = temp3

temp
# Out:
# slaegtsnavn_eng      bydelsnavn  Alder  Apple    Ash  Beech  Birch  \
# 0                   Amager Vest   53.0   94.0  173.0    0.0    6.0
# 1                    Amager Øst   21.0  109.0  222.0    1.0  280.0
# 2                    Bispebjerg    1.0  115.0  310.0   29.0  209.0
# 3                Brønshøj-Husum   10.0   12.0  128.0    1.0  109.0
# 4                      Indre By    4.0   22.0   59.0    0.0    5.0
# 5                      Nørrebro    2.0   81.0  163.0    4.0  100.0
# 6                         Valby    3.0   41.0  417.0    3.0    6.0
# 7                       Vanløse   44.0    3.0  131.0    2.0   11.0
# 8                     Vesterbro   46.0  132.0  128.0    4.0   56.0
# 9                      Østerbro   59.0   51.0  223.0   34.0    8.0
#
# slaegtsnavn_eng  Black locust  Cedar  Cherry/Plum  Chestnut  Cornus  \
# 0                       238.0    0.0        215.0       0.0     0.0
# 1                        50.0    2.0        187.0       0.0     7.0
# ...

# %% [markdown]
# To give the viewer an even better idea of the trees, pictures are added to the hovertool for each tree type. To do this a ``ColumnDataSource`` is therefor constructed for the dataframe.

# %%
source = ColumnDataSource(data=dict(temp))

colornames = ['#c6a5c1','#77c6ba','#90318e','#d3008c','#f77589','#ff28fd','#00c846','#fde1b1',
              '#9a6900','#8abf5d','#a795c6','#00753f','#755726','#00ebed','#ffbad6','#56642a',
              '#ac567c','#f9ff00','#a0e491','#b8ba01','#a77b87','#97414d','#05acc6','#855b89',
              '#79525e','#d3c37c','#018700','#c86e66','#ff49b1','#829026','#ffa52f','#009e7c',
              '#afa5ff','#6b8567','#db72c8','#5d8c90','#49a150','#c84248','#80793d','#e48eff',
              '#00d493']

treeName = ['Alder', 'Apple', 'Ash', 'Beech', 'Birch', 'Black locust', 'Cedar',
            'Cherry/Plum', 'Chestnut', 'Cornus', 'Dawn redwood', 'Elm',
            'False cypress', 'Gingko', 'Golden rain', 'Hawthorn', 'Hazel',
            'Honey locust', 'Hornbeam', 'Horse chestnut', 'Juneberry', 'Larch',
            'Linden', 'Magnolia', 'Maple', 'Minority trees', 'Not registered',
            'Oak', 'Pear', 'Pine', 'Plane', 'Poplar', 'Rowan', 'Spruce', 'Sweetgum',
            'Thuja', 'Tree of heaven', 'Tulip tree', 'Walnut', 'Willow', 'Yew']

# Initiate empty ditionary for the images
images = {}

# Add each tree with the same URL to begin with:
for tree in treeName:
    images[tree] = 'https://docs.bokeh.org/static/snakebite.jpg'
    
for tree in treeName:
    if tree == 'Cherry/Plum':
        images['Cherry/Plum'] = 'https://raw.githubusercontent.com/KristianBreddam/02806/master/Final_Project/Tree%20pictures/CherryPlum.jpg'
    else:
        #print(tree)
        images[tree] = 'https://raw.githubusercontent.com/KristianBreddam/02806/master/Final_Project/Tree%20pictures/{}.jpg'.format(tree)

# %% [markdown]
# The pictures used for the illustrations are gathered from open webpages using google in accordance with the agreement in XXX for DTU students and Lectors. The pictures are saved on GitHub and are passed to the ``images`` dictionary. Links to the original source for the pictures are given below.

# %% [markdown]
# Alder - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.pinterest.dk%2Fpin%2F222435669065105263%2F%3Famp_client_id%3DCLIENT_ID(_)%26mweb_unauth_id%3D%26simplified%3Dtrue&psig=AOvVaw3keJ8J4IexPyTLcYLM_XAI&ust=1589474197823000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCODIj_yisekCFQAAAAAdAAAAABAD<br>
# Apple - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.hiclipart.com%2Ffree-transparent-background-png-clipart-dkfoa&psig=AOvVaw0ZmkjFQ4Y-sop4bhp-UOIs&ust=1589474228985000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCPDs7YujsekCFQAAAAAdAAAAABAD<br>
# Ash - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.dreamstime.com%2Fillustration%2Fash-tree.html&psig=AOvVaw07Shgc6EJDqSnmJfxlwtPP&ust=1589474283854000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCOCdz6OjsekCFQAAAAAdAAAAABAD<br>
# Beech - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.clipartkey.com%2Fview%2FmTmJow_transparent-beech-tree-clipart-tree-no-back-ground%2F&psig=AOvVaw1En4KgcwxLoyRZ46dDn6tC&ust=1589474306525000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCMCm9K6jsekCFQAAAAAdAAAAABAD<br>
# Birch - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.colourbox.com%2Fimage%2Fbirch-tree-betula-isolated-on-white-background-image-3217771&psig=AOvVaw2Inklr6B4_Nh7loG-k9SKa&ust=1589474344949000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCJiD3MCjsekCFQAAAAAdAAAAABAD<br>
# Black locust - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.pngitem.com%2Fmiddle%2FThhxw_tree-robinia-robinia-pseudoacacia-black-locust-tree-on%2F&psig=AOvVaw3ELI3LtyLdZXREEagFEn6h&ust=1589474395175000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCMiY29ijsekCFQAAAAAdAAAAABAD<br>
# Cedar - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.clipartkey.com%2Fview%2FxwhRTb_transparent-cedar-tree-clipart-black-and-white-cedar%2F&psig=AOvVaw3HRpRjWUMNruOdb5LDauuZ&ust=1589474420223000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCIDaoOejsekCFQAAAAAdAAAAABAK<br>
# Cherry/Plum - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.pinterest.com%2Fpin%2F612208143077854971%2F&psig=AOvVaw2RVPIRANeAFE4ucyoRDdHr&ust=1589476019742000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCKi2t-epsekCFQAAAAAdAAAAABAJ<br>
# Chestnut - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.123rf.com%2Fphoto_10645691_a-chestnut-tree-standing-alone-over-white-background.html&psig=AOvVaw3YS0RBVed8PpOEFcoFarAv&ust=1589474490979000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCKDv7YaksekCFQAAAAAdAAAAABAD<br>
# Cornus - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.hiclipart.com%2Ffree-transparent-background-png-clipart-dgzba&psig=AOvVaw0HdAApRr1Bnum4qdKETD6j&ust=1589474516343000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCICOuJ-ksekCFQAAAAAdAAAAABAD<br>
# Dawn redwood - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.pngitem.com%2Fmiddle%2FiTiTihR_redwood-tree-png-transparent-png%2F&psig=AOvVaw1inhsOswYhOb7p__thaxMc&ust=1589474576988000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCKDtxq-ksekCFQAAAAAdAAAAABAD<br>
# Elm - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.dreamstime.com%2Fstock-photography-elm-tree-isolated-white-image34045562&psig=AOvVaw37P4wr9HiHCzB67GAlGYdS&ust=1589474599055000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCIjl17mksekCFQAAAAAdAAAAABAD<br>
# False cypress - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.123rf.com%2Fphoto_24419118_cypress-tree-isolated-on-white-background.html&psig=AOvVaw0WoRzcbfCAgw98z1gmjz7j&ust=1589474626452000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCMi58cqksekCFQAAAAAdAAAAABAD<br>
# Gingko - https://www.pngfuel.com/free-png/eqxeh/download<br>
# Golden rain - https://www.google.com/search?q=golden+rain+tree+clipart&tbm=isch&ved=2ahUKEwiPr_7cobHpAhWRzSoKHR5oDUEQ2-cCegQIABAA&oq=golden+rain+tree+clipart&gs_lcp=CgNpbWcQA1DHiQFYro8BYJiQAWgAcAB4AYAB-QGIAasGkgEFNS4xLjGYAQCgAQGqAQtnd3Mtd2l6LWltZw&sclient=img&ei=zyC8Xs-LBJGbqwGe0LWIBA&bih=703&biw=767#imgrc=u9D3hsM3_WRzBM<br>
# Hawthorn - https://www.google.com/url?sa=i&url=https%3A%2F%2Fpngio.com%2FPNG%2Fa90975-thorn-trees-png.html&psig=AOvVaw1OUOFJBPJwJ8otCgyefekX&ust=1589474003693000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCKCToKKisekCFQAAAAAdAAAAABAD<br>
# Hazel - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.clipart.email%2Fclipart%2Fclipart-hazel-tree-331102.html&psig=AOvVaw1Cibr1tMvFtcBJtDsAyUCo&ust=1589474130252000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCJiVi9yisekCFQAAAAAdAAAAABAD<br>
# Honey locust - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.pinterest.com%2Fpin%2F289567451021749637%2F&psig=AOvVaw2FAjRaeew9GSWkO9eBEzC5&ust=1589474712248000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCPiA2vKksekCFQAAAAAdAAAAABAD<br>
# Hornbeam - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.dreamstime.com%2Fillustration%2Fhornbeam.html&psig=AOvVaw3FFL08BY87QdE2axM43UJO&ust=1589474761951000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCLiF2IelsekCFQAAAAAdAAAAABAD<br>
# Horse chestnut - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.123rf.com%2Fphoto_20744570_isolated-horse-chestnut-tree-on-a-white-background.html&psig=AOvVaw3JjrRl6RHR4U0jplRA9lZL&ust=1589474888306000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCID-68SlsekCFQAAAAAdAAAAABAX<br>
# Juneberry - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.americangardener.com%2F15-seeds-amelanchier-lamarckii-june-berry-tree%2F&psig=AOvVaw1ycVSsK3uOSxwPpuxmBlUM&ust=1589475539202000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCIDauvynsekCFQAAAAAdAAAAABAD<br>
# Larch - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.dreamstime.com%2Fillustration%2Flarch.html&psig=AOvVaw3zZgbqyJN5Te7bkoS1Hn1X&ust=1589475618997000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCLiy3aGosekCFQAAAAAdAAAAABAE<br>
# Linden - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.uihere.com%2Ffree-cliparts%2Fbig-crown-linden-tree-picture-material-5223019&psig=AOvVaw25kRjMyl8NZ_1YACA0obXb&ust=1589475663147000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCOCTkLiosekCFQAAAAAdAAAAABAJ<br>
# Magnolia - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.pinterest.com%2Fpin%2F84442561733145921%2F&psig=AOvVaw34UVWirqu5TUkWNjhcECPq&ust=1589474466277000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCMCS5_qjsekCFQAAAAAdAAAAABAD<br>
# Maple - https://www.clipartkey.com/view/iiohbTo_tree-japanese-trees-sugar-red-maple-clipart-red/<br>
# Minority trees - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.vecteezy.com%2Fvector-art%2F334055-textured-trees-clipart&psig=AOvVaw1IDw3QBz38vo85I_WEvmCU&ust=1589476440323000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCJixmqursekCFQAAAAAdAAAAABAT<br>
# Not registered - https://www.netclipart.com/isee/ibwhhJ_question-mark-png-transparent-question-marks-clipart-black/<br>
# Oak - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.clipartkey.com%2Fview%2FTRxhhw_clip-art-green-oak-tree-tree-with-white%2F&psig=AOvVaw3eqFHnL-YRu2avi1jR8j8Z&ust=1589476846136000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCMDH4emssekCFQAAAAAdAAAAABAQ<br>
# Pear - https://www.google.com/url?sa=i&url=https%3A%2F%2Fen.clipdealer.com%2Fphoto%2Fmedia%2FA%3A56887958&psig=AOvVaw0nNc-fQLAdxN-jmZEEZepM&ust=1589476693405000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCKDtoqOssekCFQAAAAAdAAAAABAD<br>
# Pine - https://www.clipartkey.com/downpng/JThxh_realistic-pine-tree-png-clip-art-transparent-pine/<br>
# Plane - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.123rf.com%2Fphoto_20744561_isolated-plane-tree-on-a-white-background.html&psig=AOvVaw3IiCYxWbHduHG59ISpNqyg&ust=1589477304447000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCOjx8cWusekCFQAAAAAdAAAAABAI<br>
# Poplar - https://www.cleanpng.com/png-crown-ampquot-amp-7331055/download-png.html<br>
# Rowan - https://www.google.com/search?q=rowan+tree+white+background&tbm=isch&ved=2ahUKEwjN-IOXr7HpAhUOwaYKHSIQApsQ2-cCegQIABAA&oq=rowan+tree+white+background&gs_lcp=CgNpbWcQAzIECCMQJ1DfCVjfCWDCDWgAcAB4AIABZYgBZZIBAzAuMZgBAKABAaoBC2d3cy13aXotaW1n&sclient=img&ei=6i68Xs3bG46CmwWioIjYCQ&bih=703&biw=766#imgrc=h0nk3GsnXDBVgM<br>
# Spruce - https://www.google.com/url?sa=i&url=https%3A%2F%2Feu.clipdealer.com%2Fphoto%2Fmedia%2FA%3A22690248&psig=AOvVaw3UAzuwxiWY5XbsMMsuUjtq&ust=1589477559496000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCJC4_r6vsekCFQAAAAAdAAAAABAJ<br>
# Sweetgum - https://www.cleanpng.com/png-american-sweetgum-acer-ginnala-tree-plant-autumn-l-735324/download-png.html<br>
# Thuja - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.pinterest.com%2Fpin%2F535787686910699031%2F&psig=AOvVaw26vriHeeehudJ5hmleljnQ&ust=1589477741366000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCMDRlZSwsekCFQAAAAAdAAAAABAD<br>
# Tree of heavn - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.dreamstime.com%2Fphotos-images%2Fgreen-leaf-tree-heaven-isolated-white.html&psig=AOvVaw0Ih3gxx0YtOdoIDZhYy9CW&ust=1589478544438000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCOiL_5OzsekCFQAAAAAdAAAAABAO<br>
# Tulip tree - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.pngitem.com%2Fmiddle%2FoTohJ_tulip-tree-png-transparent-png%2F&psig=AOvVaw21KfT9x0VekBp6aW6QG7JE&ust=1589478020761000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCICZ-JmxsekCFQAAAAAdAAAAABAI<br>
# Walnut - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.pinterest.dk%2Fpin%2F604678687452094902%2F&psig=AOvVaw37oU-wvL5ybivZojPNfGNg&ust=1589478071644000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCLiC6bGxsekCFQAAAAAdAAAAABAD<br>
# Willow - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.pinterest.com%2Fpin%2F13792342586960628%2F&psig=AOvVaw03As-nayN_n0w1atpTItiQ&ust=1589478122417000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCMD3hMqxsekCFQAAAAAdAAAAABAD<br>
# Yew - https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.clipart.email%2Fclipart%2Fyew-tree-clipart-86997.html&psig=AOvVaw1Y4Pgo1_h2QytTQHmRWXFJ&ust=1589478267261000&source=images&cd=vfe&ved=0CAMQjB1qFwoTCIiwuZGysekCFQAAAAAdAAAAABAI

# %% [markdown]
# To reduce the space needed to show the stackedbar chart a horizontal version of the plot is constructed. To add the pictures to the hovertool the tooltip is coded used HTML coding.

# %%
# Create an empty figure
p = figure(y_range = temp['bydelsnavn'].values,plot_width = 900, plot_height=700,
           toolbar_sticky = False,tools = 'pan,wheel_zoom,reset')

# Stacked bar chart
renderers = p.hbar_stack(stackers=treeName,y='bydelsnavn',source=source,
            height=0.8, color = colornames)

for r in renderers:
    tree = r.name
    hover = HoverTool(tooltips=f"""\
    <div> 
        <!-- IMAGE -->
        <div>
          <img
              style="max-width: 100px; max-height: 130px; margin:0px 0px 5px 0px;" 
              src="{images[tree]}"
          ></img>
        </div> 
        
        <!-- TREE TYPE -->
        <div>
          <span style ="font-size: 12px;">Type:</span>
          <span style ="font-size: 12px; font-weight: bold;">{tree}</span>
        </div>
        
        <!-- AMOUNT -->
        <div>
          <span style ="font-size: 12px;">Amount:</span>
          <span style ="font-size: 12px; font-weight: bold;">@{{{tree}}}</span>
        </div>
        
        <!-- TREES OUT OF DISTRICT -->
        <div>
          <span style ="font-size: 12px;">
          Out of trees in the district:</span>
          <span style ="font-size: 12px; font-weight: bold;">
          @{{{tree}_d}}{{0.0}} %</span>
        </div>
        
        <!-- TREES OUT OF ALL TREES -->
        <div>
          <span style ="font-size: 12px;">
          Out of all {tree} trees:</span>
          <span style ="font-size: 12px; font-weight: bold;">
          @{{{tree}_p}}{{0.0}} %</span>
        </div>
         
    </div>
    """, renderers=[r],toggleable=False)
    p.add_tools(hover)

# remove the grid
p.xgrid.grid_line_color=None
p.ygrid.grid_line_color=None
# Make sure bars stat at 0
p.x_range.start = 0
# remove - y-axis
p.xaxis.visible = False
# Remove the grey box around the plot
p.outline_line_color = None
# Remove tool bar logo
p.toolbar.logo = None
# Extend the plot borders so the tooltips shows
p.min_border_bottom =80
p.min_border_top=70
    
show(p)
# Out:
#   <div class="bk-root" id="97e81bef-9af3-4f9e-91fb-878c3e2f0a9e" data-root-id="3763"></div>

# %% [markdown]
# The chart shows that the largest porpotion for all districts are made out of 'Not registered' trees. it can further be seen that distribution of the tree types is more uniform for some districts like Amager Øst than for example Indre By. This means that Indre By would be much harder hit if a dicease among Linden trees were to break out as more than 1/4 of the trees are Linden trees. Once again details on demand ard added in the from of a hovertool. The pictures further add a nice dimension to the chart as the viewer get a chance to actually see the specific tree types.

# %% [markdown]
# ## Genre
# This section of the notebook aims to explain the general ideas about the genre that the aouthers had while working.

# %% [markdown]
# #### Genre
# The story has been created as a series of anotated bar charts and maps. This places the storys genre as a mixture between the second genre: Annotated Graph/ Map and the sixth genre: Slide show. As each plot can be seen as a new slide in the storyline.
# This was chosen as it resemples the Interactive slide show [4.4.2 Interactive Slideshow, Segal and Heer], which is highlighted as a balanced mix of the reader and author driven approaches. This allows the reader to seek more information at different stages of the narrative while still following the overall linear story approach laid out by the authors.
#
# # Hvad menes der med 'second genre' og 'sixth genre'? :)
#
# #### Visual narrative
# The visuals were structured using a common visual platform, using the same colours for each tree type throughout the different plots spanning the shift between bar chart and visualized geographical data. The visuals consists of a mixof  maps and multiple kinds of bar charts with the colour theme staying semantically consistent and uses the same axes throughout. This allows the reader to easily navigate between the different plots without having to use unecessary time and effort in understanding each new plot.
#
# The visuals are highlighted using feature distinction in terms of different coulors for different features within the same map increasing the visual salience. An example of this is the map showing the loneliest tree, where the two lonliest trees are highlighted in different colors while still showing all other trees. Further precision of certain parts of the plots can be obtained using the zoom feature. The zoom feature is helpfull when attempting to distinct between trees that are closely grouped or when viewing tree families with few trees in the stacked bar chart.
#
# The transistions between each plot is done manually by scrolling to the next plot while reading the text accompanying each plot. This allows the reader to understand the takeaways of the previous plot and the introduction to the next.
#
# #### Narrative structure
# The narrative is as mentioned above structured linearly while allowing for reader exploration throughtout the story. This ensures that the story is told in a sensible way with a causal relationship within sections.
# The main parts of the narrative are shown in the first plots with the remaining encouraging active participation during a walk highlighting interesting special cases (donor, age, etc.) that are not as significant when looking at the overall distribution.
# Not all sections are linked which would allow for a different ordering of the content.
#
# The storyline has a high degree of interactivity as most plots has at least one point of interaction.
# The interaction tools have been made using the design strategy of Details-on-demand [3.2 Budget Forecasts, Compared With Reality, Segal and Heer]. This allows the reader to discover additional information when requested, which ensures that the reader is not overwelmed by a large amount of data at once. This design strategy has been implemented by using hover tools and filtering options, which allows the reader to only receive the desired information.
#
# The visuals are first introduced by captions and an introductory text which explains the next visual. Afterwards a summary of the key takeaways are shown leading to the next visual. This ensures that the reader understands what can be learned from each visual.

# %% [markdown]
# ## Visualization
# **FROM PROJECT DESCRIPTION:** Explain the visualizations you've chosen. Why are they right for the story you want to tell?

# %% [markdown]
# The aim of the story is to show the geographical distribution of the trees of Copenhagen.
# The geographical maps gives the reader a sense of familiarity and allow the reader to explore the data in reality on a walk where it is possible to navigate to certain trees.
#
# Bar charts are excellent tools for showing distributions and for comparing different values by using the eye as a data analyzation tool.
#
# Stacked bar chart sammenligne total antal træer og træer af hver type i et. God måde at præsentere flerer forskellige slags data i et plot.
#
# ingen akser, simplicitet
#
# Brede befolkning mindsker barrieren
#
# Skift i mellem ved at præsentere læseren for nye versioner af den samme type plot uden
#
# horizontalt stacked så det er nemmere at læse og udnytter bredden bedre

# %% [markdown]
# ## Discussion
# **FROM PROJECT DESCRIPTION:** Think critically about your creation. What went well? What is still missing? What could be improved?, Why?

# %% [markdown]
# ## Contribution
# **FROM PROJECT DESCRIPTION:** You should write (just briefly) which group member was the main responsible for which elements of the assignment. (I want you guys to understand every part of the assignment, but usually there is someone who took lead role on certain portions of the work. That's what you should explain).
# It is not OK simply to write "All group members contributed equally".
